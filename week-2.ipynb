# %%
import pandas as pd
df=pd.read_csv("Car_sales.csv")
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
#     Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0      Passenger               21.5         1.8        140     101.2  67.3
# 1      Passenger               28.4         3.2        225     108.1  70.3
# 2      Passenger                  .         3.2        225     106.9  70.6
# 3      Passenger                 42         3.5        210     114.6  71.4
# 4      Passenger              23.99         1.8        150     102.6  68.2
# ..           ...                ...         ...        ...       ...   ...
# 152    Passenger               24.4         1.9        160     100.5  67.6
# 153    Passenger               27.5         2.4        168     104.9  69.3
# 154    Passenger               28.8         2.4        168     104.9  69.3
# 155    Passenger               45.5         2.3        236     104.9  71.5
# 156    Passenger                 36         2.9        201     109.9  72.1
#
#     Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 0    172.4       2.639          13.2              28      2-Feb-14
# 1    192.9       3.517          17.2              25      6-Mar-15
# 2      192        3.47          17.2              26      1-Apr-14
# 3    196.6        3.85            18              22      3-Oct-15
# 4      178       2.998          16.4              27     10-Aug-15
# ..     ...         ...           ...             ...           ...
# 152  176.6       3.042          15.8              25     21-Sep-15
# 153  185.9       3.208          17.9              25     24-Nov-14
# 154  186.2       3.259          17.9              25     25-Jun-15
# 155  185.7       3.601          18.5              23     26-Apr-15
# 156  189.8         3.6          21.1              24     14-Nov-15
#
# [157 rows x 15 columns]

# %%
#1. Read top five values
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 0  172.4       2.639          13.2              28      2-Feb-14
# 1  192.9       3.517          17.2              25      6-Mar-15
# 2    192        3.47          17.2              26      1-Apr-14
# 3  196.6        3.85            18              22      3-Oct-15
# 4    178       2.998          16.4              27     10-Aug-15

# %%
#2. Print dataframe info_data types of each column
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
df.shape
# Out:
# (157, 15)

# %%
df=df.drop_duplicates()
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
#     Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0      Passenger               21.5         1.8        140     101.2  67.3
# 1      Passenger               28.4         3.2        225     108.1  70.3
# 2      Passenger                  .         3.2        225     106.9  70.6
# 3      Passenger                 42         3.5        210     114.6  71.4
# 4      Passenger              23.99         1.8        150     102.6  68.2
# ..           ...                ...         ...        ...       ...   ...
# 152    Passenger               24.4         1.9        160     100.5  67.6
# 153    Passenger               27.5         2.4        168     104.9  69.3
# 154    Passenger               28.8         2.4        168     104.9  69.3
# 155    Passenger               45.5         2.3        236     104.9  71.5
# 156    Passenger                 36         2.9        201     109.9  72.1
#
#     Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 0    172.4       2.639          13.2              28      2-Feb-14
# 1    192.9       3.517          17.2              25      6-Mar-15
# 2      192        3.47          17.2              26      1-Apr-14
# 3    196.6        3.85            18              22      3-Oct-15
# 4      178       2.998          16.4              27     10-Aug-15
# ..     ...         ...           ...             ...           ...
# 152  176.6       3.042          15.8              25     21-Sep-15
# 153  185.9       3.208          17.9              25     24-Nov-14
# 154  186.2       3.259          17.9              25     25-Jun-15
# 155  185.7       3.601          18.5              23     26-Apr-15
# 156  189.8         3.6          21.1              24     14-Nov-15
#
# [157 rows x 15 columns]

# %%
#5. Print number of rows and columns after dropping duplicates
df.shape
# Out:
# (157, 15)

# %%
#6. Print summary statistics for numerical variables
df.describe()
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
#7. Print number of missing values in each column
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
#8. Drop the column with most missing values
df.isnull().sum().idxmax()
df.drop(columns='Manufacturer')
# Out:
#                  Model  Sales in thousands 4-year resale value Vehicle type  \
# 0    Integra                        16.919               16.36    Passenger
# 1    TL                             39.384              19.875    Passenger
# 2    CL                             14.114              18.225    Passenger
# 3    RL                              8.588              29.725    Passenger
# 4    A4                             20.397              22.255    Passenger
# ..                 ...                 ...                 ...          ...
# 152  V40                             3.545                   .    Passenger
# 153  S70                            15.245                   .    Passenger
# 154  V70                            17.531                   .    Passenger
# 155  C70                             3.493                   .    Passenger
# 156  S80                            18.969                   .    Passenger
#
#     Price in thousands Engine size Horsepower Wheelbase Width Length  \
# 0                 21.5         1.8        140     101.2  67.3  172.4
# 1                 28.4         3.2        225     108.1  70.3  192.9
# 2                    .         3.2        225     106.9  70.6    192
# 3                   42         3.5        210     114.6  71.4  196.6
# 4                23.99         1.8        150     102.6  68.2    178
# ..                 ...         ...        ...       ...   ...    ...
# 152               24.4         1.9        160     100.5  67.6  176.6
# 153               27.5         2.4        168     104.9  69.3  185.9
# 154               28.8         2.4        168     104.9  69.3  186.2
# 155               45.5         2.3        236     104.9  71.5  185.7
# 156                 36         2.9        201     109.9  72.1  189.8
#
#     Curb weight Fuel capacity Fuel efficiency Latest Launch
# 0         2.639          13.2              28      2-Feb-14
# 1         3.517          17.2              25      6-Mar-15
# 2          3.47          17.2              26      1-Apr-14
# 3          3.85            18              22      3-Oct-15
# 4         2.998          16.4              27     10-Aug-15
# ..          ...           ...             ...           ...
# 152       3.042          15.8              25     21-Sep-15
# 153       3.208          17.9              25     24-Nov-14
# 154       3.259          17.9              25     25-Jun-15
# 155       3.601          18.5              23     26-Apr-15
# 156         3.6          21.1              24     14-Nov-15
#
# [157 rows x 14 columns]

# %%
#9. Drop the rows with categorical missing values
cols=df.select_dtypes(include='object').columns
df[df[cols].isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
#10. Import the rows with numerical missing values
num_rows=df.select_dtypes(include='number').columns
df[df[num_rows].isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
#11. Sort the data w.r.t price_find the details of the most and the least expensive cars
df=df.sort_values(by=['Price in thousands'],ascending=[True])
print(df.iloc[-1])
df.iloc[0]
# Out:
# Manufacturer               Hyundai
# Model                  Accent
# Sales in thousands                41.184
# 4-year resale value                 5.86
# Vehicle type                   Passenger
# Price in thousands                 9.699
# Engine size                          1.5
# Horsepower                            92
# Wheelbase                           96.1
# Width                               65.7
# Length                             166.7
# Curb weight                         2.24
# Fuel capacity                       11.9
# Fuel efficiency                       31
# Latest Launch                   9-Oct-14
# Name: 62, dtype: object
# Manufacturer               Acura
# Model                  CL
# Sales in thousands                14.114
# 4-year resale value               18.225
# Vehicle type                   Passenger
# Price in thousands                     .
# Engine size                          3.2
# Horsepower                           225
# Wheelbase                          106.9
# Width                               70.6
# Length                               192
# Curb weight                         3.47
# Fuel capacity                       17.2
# Fuel efficiency                       26
# Latest Launch                   1-Apr-14
# Name: 2, dtype: object

# %%
#12. Write a function to find min and max values of any column
def find_min_max(column_name,df):
    if column_name in df.columns:
        min_row=df[column_name].min()
        max_row=df[column_name].max()
        return min_row,max_row

# %%
#13. Call the above function to find min max of horse power, length, fuel efficiency
min_price,max_price=find_min_max('Fuel efficiency',df)
print(min_price)
max_price
# Out:
# .
# '45'

# %%
#14. Plot histogram of continuous numerical variable :price,sales,hoursepower,fuelefficiency
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("Car_sales.csv")
columns = ["Price in thousands", "Sales in thousands",
"Horsepower", "Fuel efficiency"]
fig, axes = plt.subplots(2, 2, figsize=(12, 10)) # 2 rows and 2columns
for i, column in enumerate(columns):
 # Determine row and column index for the subplot
 ax = axes[i // 2, i % 2]

 # Plot histogram
 sns.histplot(df[column], kde=True, ax=ax)


 ax.set_title(f"Histogram of {column.capitalize()}")
 ax.set_xlabel(column.capitalize())
 ax.set_ylabel("Frequency")

# %%
#15. Probability density distribution of continuous numerical variable-length
from scipy.stats import gaussian_kde
df=pd.read_csv('Car_sales.csv')
df.columns=df.columns.str.strip()
if 'Length' in df.columns:
    df['Length']=pd.to_numeric(df['Length'],errors='coerce')
    data=df['Length'].dropna()
    kde=gaussian_kde(data)
    den=kde.evaluate(data)
    result=pd.DataFrame({'Length':kde,'Density':den})
    print(result.head())
# Out:
#                                               Length   Density
# 0  <scipy.stats._kde.gaussian_kde object at 0x7fc...  0.016206
# 1  <scipy.stats._kde.gaussian_kde object at 0x7fc...  0.027570
# 2  <scipy.stats._kde.gaussian_kde object at 0x7fc...  0.028122
# 3  <scipy.stats._kde.gaussian_kde object at 0x7fc...  0.023728
# 4  <scipy.stats._kde.gaussian_kde object at 0x7fc...  0.023772

# %%
#16. Count by category –group by manufacture
df.groupby('Manufacturer').count()
# Out:
#                Model  Sales in thousands  4-year resale value  Vehicle type  \
# Manufacturer
# Acura              4                   4                    4             4
# Audi               3                   3                    3             3
# BMW                3                   3                    3             3
# Buick              4                   4                    4             4
# Cadillac           5                   5                    5             5
# Chevrolet          9                   9                    9             9
# Chrysler           7                   7                    7             7
# Dodge             11                  11                   11            11
# Ford              11                  11                   11            11
# Honda              5                   5                    5             5
# Hyundai            3                   3                    3             3
# Infiniti           1                   1                    1             1
# Jaguar             1                   1                    1             1
# Jeep               3                   3                    3             3
# Lexus              6                   6                    6             6
# Lincoln            3                   3                    3             3
# Mercedes-Benz      9                   9                    9             9
# Mercury            6                   6                    6             6
# Mitsubishi         7                   7                    7             7
# Nissan             7                   7                    7             7
# Oldsmobile         6                   6                    6             6
# Plymouth           4                   4                    4             4
# Pontiac            6                   6                    6             6
# Porsche            3                   3                    3             3
# Saab               2                   2                    2             2
# Saturn             5                   5                    5             5
# Subaru             2                   2                    2             2
# Toyota             9                   9                    9             9
# Volkswagen         6                   6                    6             6
# Volvo              6                   6                    6             6
#
#                Price in thousands  Engine size  Horsepower  Wheelbase  Width  \
# Manufacturer
# Acura                           4            4           4          4      4
# Audi                            3            3           3          3      3
# BMW                             3            3           3          3      3
# Buick                           4            4           4          4      4
# Cadillac                        5            5           5          5      5
# Chevrolet                       9            9           9          9      9
# Chrysler                        7            7           7          7      7
# Dodge                          11           11          11         11     11
# Ford                           11           11          11         11     11
# Honda                           5            5           5          5      5
# Hyundai                         3            3           3          3      3
# Infiniti                        1            1           1          1      1
# Jaguar                          1            1           1          1      1
# Jeep                            3            3           3          3      3
# Lexus                           6            6           6          6      6
# Lincoln                         3            3           3          3      3
# Mercedes-Benz                   9            9           9          9      9
# Mercury                         6            6           6          6      6
# Mitsubishi                      7            7           7          7      7
# Nissan                          7            7           7          7      7
# Oldsmobile                      6            6           6          6      6
# Plymouth                        4            4           4          4      4
# Pontiac                         6            6           6          6      6
# Porsche                         3            3           3          3      3
# Saab                            2            2           2          2      2
# Saturn                          5            5           5          5      5
# Subaru                          2            2           2          2      2
# Toyota                          9            9           9          9      9
# Volkswagen                      6            6           6          6      6
# Volvo                           6            6           6          6      6
#
#                Length  Curb weight  Fuel capacity  Fuel efficiency  \
# Manufacturer
# Acura               4            4              4                4
# Audi                3            3              3                3
# BMW                 3            3              3                3
# Buick               4            4              4                4
# Cadillac            5            5              5                5
# Chevrolet           9            9              9                9
# Chrysler            6            7              7                7
# Dodge              11           11             11               11
# Ford               11           11             11               11
# Honda               5            5              5                5
# Hyundai             3            3              3                3
# Infiniti            1            1              1                1
# Jaguar              1            1              1                1
# Jeep                3            3              3                3
# Lexus               6            6              6                6
# Lincoln             3            3              3                3
# Mercedes-Benz       9            9              9                9
# Mercury             6            6              6                6
# Mitsubishi          7            7              7                7
# Nissan              7            7              7                7
# Oldsmobile          6            6              6                6
# Plymouth            4            4              4                4
# Pontiac             6            6              6                6
# Porsche             3            3              3                3
# Saab                2            2              2                2
# Saturn              5            5              5                5
# Subaru              2            2              2                2
# Toyota              9            9              9                9
# Volkswagen          6            6              6                6
# Volvo               6            6              6                6
#
#                Latest Launch
# Manufacturer
# Acura                      4
# Audi                       3
# BMW                        3
# Buick                      4
# Cadillac                   5
# Chevrolet                  9
# Chrysler                   7
# Dodge                     11
# Ford                      11
# Honda                      5
# Hyundai                    3
# Infiniti                   1
# Jaguar                     1
# Jeep                       3
# Lexus                      6
# Lincoln                    3
# Mercedes-Benz              9
# Mercury                    6
# Mitsubishi                 7
# Nissan                     7
# Oldsmobile                 6
# Plymouth                   4
# Pontiac                    6
# Porsche                    3
# Saab                       2
# Saturn                     5
# Subaru                     2
# Toyota                     9
# Volkswagen                 6
# Volvo                      6

# %%
#17. Select all numerical variables
res=df.select_dtypes(include=['number']).columns
res
# Out:
# Index(['Sales in thousands', 'Length'], dtype='object')

# %%
#18. Print correlation coefficient value of price and sales
df['Price in thousands']=pd.to_numeric(df['Price in thousands'],errors='coerce')
df['Sales in thousands']=pd.to_numeric(df['Sales in thousands'],errors='coerce')
res=df['Price in thousands'].corr(df['Sales in thousands'])
res
# Out:
# -0.3047344541294122

# %%
#19. Plot correlation of price and sales using scatterplot
plt.scatter(x=df["Price in thousands"],y=df['Sales in thousands'])
plt.show()

# %%
#20.Pair plot
sns.pairplot(df)

# %%
#21. Boxplot of sales of different manufacturer
plt.figure(figsize=(10,12))
sns.boxplot(x=df['Manufacturer'],y=df['Sales in thousands'])
plt.xticks(rotation=45)
plt.show()

# %%
#22. Boxplot of other numerical variables w.r.t manufacture
cols=df.select_dtypes(include=['number']).columns
for i in cols:
    sns.boxplot(data=df,x='Manufacturer',y=i)
    plt.show()

# %%
#23. Divide the data into input and output y=sales in thousand, x=all other variables
x=df.drop(columns='Sales in thousands')
y=df['Sales in thousands']
x.shape
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
#     Vehicle type  Price in thousands Engine size Horsepower Wheelbase Width  \
# 0      Passenger               21.50         1.8        140     101.2  67.3
# 1      Passenger               28.40         3.2        225     108.1  70.3
# 2      Passenger                 NaN         3.2        225     106.9  70.6
# 3      Passenger               42.00         3.5        210     114.6  71.4
# 4      Passenger               23.99         1.8        150     102.6  68.2
# ..           ...                 ...         ...        ...       ...   ...
# 152    Passenger               24.40         1.9        160     100.5  67.6
# 153    Passenger               27.50         2.4        168     104.9  69.3
# 154    Passenger               28.80         2.4        168     104.9  69.3
# 155    Passenger               45.50         2.3        236     104.9  71.5
# 156    Passenger               36.00         2.9        201     109.9  72.1
#
#      Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 0     172.4       2.639          13.2              28      2-Feb-14
# 1     192.9       3.517          17.2              25      6-Mar-15
# 2     192.0        3.47          17.2              26      1-Apr-14
# 3     196.6        3.85            18              22      3-Oct-15
# 4     178.0       2.998          16.4              27     10-Aug-15
# ..      ...         ...           ...             ...           ...
# 152   176.6       3.042          15.8              25     21-Sep-15
# 153   185.9       3.208          17.9              25     24-Nov-14
# 154   186.2       3.259          17.9              25     25-Jun-15
# 155   185.7       3.601          18.5              23     26-Apr-15
# 156   189.8         3.6          21.1              24     14-Nov-15
#
# [157 rows x 15 columns]

# %%
#24. Encode other categorical variables using label encoder
from sklearn.preprocessing import LabelEncoder
lebel_encoders={}
cols=df.select_dtypes(include=['object']).columns
for i in cols:
    le=LabelEncoder()
    x[i]=le.fit_transform(x[i])
    label_encoders=le
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
#     Vehicle type  Price in thousands Engine size Horsepower Wheelbase Width  \
# 0      Passenger               21.50         1.8        140     101.2  67.3
# 1      Passenger               28.40         3.2        225     108.1  70.3
# 2      Passenger                 NaN         3.2        225     106.9  70.6
# 3      Passenger               42.00         3.5        210     114.6  71.4
# 4      Passenger               23.99         1.8        150     102.6  68.2
# ..           ...                 ...         ...        ...       ...   ...
# 152    Passenger               24.40         1.9        160     100.5  67.6
# 153    Passenger               27.50         2.4        168     104.9  69.3
# 154    Passenger               28.80         2.4        168     104.9  69.3
# 155    Passenger               45.50         2.3        236     104.9  71.5
# 156    Passenger               36.00         2.9        201     109.9  72.1
#
#      Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 0     172.4       2.639          13.2              28      2-Feb-14
# 1     192.9       3.517          17.2              25      6-Mar-15
# 2     192.0        3.47          17.2              26      1-Apr-14
# 3     196.6        3.85            18              22      3-Oct-15
# 4     178.0       2.998          16.4              27     10-Aug-15
# ..      ...         ...           ...             ...           ...
# 152   176.6       3.042          15.8              25     21-Sep-15
# 153   185.9       3.208          17.9              25     24-Nov-14
# 154   186.2       3.259          17.9              25     25-Jun-15
# 155   185.7       3.601          18.5              23     26-Apr-15
# 156   189.8         3.6          21.1              24     14-Nov-15
#
# [157 rows x 15 columns]

# %%
#25. Encode categorical variable vehicle type using one-hot encoder
df=pd.get_dummies(df,columns=['Vehicle type'],drop_first=True)
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
#      Price in thousands Engine size Horsepower Wheelbase Width  Length  \
# 0                 21.50         1.8        140     101.2  67.3   172.4
# 1                 28.40         3.2        225     108.1  70.3   192.9
# 2                   NaN         3.2        225     106.9  70.6   192.0
# 3                 42.00         3.5        210     114.6  71.4   196.6
# 4                 23.99         1.8        150     102.6  68.2   178.0
# ..                  ...         ...        ...       ...   ...     ...
# 152               24.40         1.9        160     100.5  67.6   176.6
# 153               27.50         2.4        168     104.9  69.3   185.9
# 154               28.80         2.4        168     104.9  69.3   186.2
# 155               45.50         2.3        236     104.9  71.5   185.7
# 156               36.00         2.9        201     109.9  72.1   189.8
#
#     Curb weight Fuel capacity Fuel efficiency Latest Launch  \
# 0         2.639          13.2              28      2-Feb-14
# 1         3.517          17.2              25      6-Mar-15
# 2          3.47          17.2              26      1-Apr-14
# 3          3.85            18              22      3-Oct-15
# 4         2.998          16.4              27     10-Aug-15
# ..          ...           ...             ...           ...
# 152       3.042          15.8              25     21-Sep-15
# 153       3.208          17.9              25     24-Nov-14
# 154       3.259          17.9              25     25-Jun-15
# 155       3.601          18.5              23     26-Apr-15
# 156         3.6          21.1              24     14-Nov-15
#
#      Vehicle type_Passenger
# 0                      True
# 1                      True
# 2                      True
# 3                      True
# 4                      True
# ..                      ...
# 152                    True
# 153                    True
# 154                    True
# 155                    True
# 156                    True
#
# [157 rows x 15 columns]

# %%
#26.Split the data set into train and test set 70% train set 10% test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.10,random_state=42)
x_train.shape,y_train.shape
# Out:
# ((141, 14), (141,))

# %%
#27. Apply feature scaling on numerical variables
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
cols=df.select_dtypes(include=['number']).columns
df[cols]=sd.fit_transform(df[cols])
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                     -0.532042               16.36
# 1  Acura          TL                          -0.200761              19.875
# 2  Acura          CL                          -0.573406              18.225
# 3  Acura          RL                          -0.654896              29.725
# 4  Audi           A4                          -0.480754              22.255
#
#    Price in thousands Engine size Horsepower Wheelbase Width    Length  \
# 0           -0.411789         1.8        140     101.2  67.3 -1.116140
# 1            0.070551         3.2        225     108.1  70.3  0.415009
# 2                 NaN         3.2        225     106.9  70.6  0.347788
# 3            1.021248         3.5        210     114.6  71.4  0.691363
# 4           -0.237727         1.8        150     102.6  68.2 -0.697875
#
#   Curb weight Fuel capacity Fuel efficiency Latest Launch  \
# 0       2.639          13.2              28      2-Feb-14
# 1       3.517          17.2              25      6-Mar-15
# 2        3.47          17.2              26      1-Apr-14
# 3        3.85            18              22      3-Oct-15
# 4       2.998          16.4              27     10-Aug-15
#
#    Vehicle type_Passenger
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True
